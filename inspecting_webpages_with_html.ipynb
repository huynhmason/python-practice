# %% [markdown]
# First video in the webscraping series even though it appears second in the webscraping playlist

# %% [markdown]
# # HTML and Inspecting a Web Page
# https://www.scrapethissite.com/pages/forms/
#
# There was no actual coding in this video tutorial. It was just showing what an HTML script looks like, and how to inspect a web page.
